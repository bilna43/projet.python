# %%
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import pandas as pd
import numpy as np
import import_ipynb
import nettoyage_bases
import Stat_descr
import Cartes
import Modelisation
# Out:
# importing Jupyter notebook from nettoyage_bases.ipynb
# importing Jupyter notebook from Stat_descr.ipynb
# importing Jupyter notebook from Cartes.ipynb
# importing Jupyter notebook from Modelisation.ipynb

# %% [markdown]
# # Compte rendu du Projet Python
#
# ### 1) Analyse descriptive des données

# %%
Cartes.Carte_conso_brute_reg(4)
#La fonction prend en argument le mois qui correspond à la consommation brute agrégée de gaz et électricité qu'on veut visualiser
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
Stat_descr.plot_conso_Fr_2020()
# Out:
# <string>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# L'intérêt de ce graphique est d'illustrer les disparités de consommations d'énergies au sein d'une saison. Nous évoquerons plus tard les disparités entre les saisons, mais il est important de souligner que les pics de consommations d'énergies sont présent lors des températures extrêmes à l'instar du pic au sein du mois de janvier allant jusqu'à 6000 MW

# %%
Stat_descr.cor_elec_gaz()
#Correspond au coefficient de correlation de Pearson

# %% [markdown]
# Le coefficient de 0.97 montre que la consommation de gaz et d’électricité est fortement
# corrélé. On pourra donc par moment se concentrer sur l'une ou l'autre pour simplifier.

# %%
Stat_descr.plot_conso_gaz_ete_hiver()
# Out:
# <string>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# On observe que la saison a un impact important sur le niveau de consommation moyen de gaz par
# habitant. De fait, celui-ci passe d'environ 530 W/h avant 5 heures du matin en été à environ 880 en hiver soit un augmentation de plus de 50%. En postulant que cette différence est en grande partie due au climat, elle justifie l'intérêt de notre projet. De fait, le climat ayant une incidence sur la consommation de gaz il est intéressant d'étudier l'impact des évolutions climatique future sur notre consommation d'énergie.

# %%
Stat_descr.plot_conso_elec_ete_hiver()
# Out:
# <string>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# De même que pour le gaz, on observe une variation de la consommation d'électricité entre l'été et l'hiver. Celle-ci est moins importante que pour le gaz étant comprise entre 100 et 200 W/h. C'est donc une augmentation d'environ 25% soit deux fois moins que celle du gaz ce qui nous permet de relativiser la corrélation entre la consommation de gaz et d'électricité.

# %%
Stat_descr.conso_elec_region()
# Out:
# <string>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# On se rend compte que la consommation d’électricité en été par habitant n’est pas uniformément répartie en France. De fait, il y a une différence de consommation d’environ 300 Wh entre les habitants de la région  Provence Alpes Cote d’Azur (PACA) et ceux de la région Ile de France (IDF). Mais aussi une différence d’environ 100 Wh entre la Bretagne et la Normandie. Ces différences illustrent la difficulté de notre projet, de fait elles soulignent que le climat n’est pas la seule variable explicative des niveaux de consommations entre les régions. Entre l’IDF et la région PACA par exemple, le climat joue certainement un rôle, mais la différence s’explique aussi par d’autres variables. Tout d’abord il y a une forte différence de densité d’habitant au mètre carré. Celle-ci est bien plus importante en IDF qu’en PACA rendant par exemple les surfaces à climatiser par habitant moins importante. Ensuite on peut souligner le nombre de personnes séjournant dans la région qui est différent du nombre d’habitants en été du fait du Tourisme. Ainsi, de nombreux facteurs sont déterminant dans la consommation d’énergie, ce qui ne signifie pas qu’un travail de prédiction ne soit pas intéressant, mais qu’il doit être compris avec ses limites inhérentes aux limites des données.

# %%
Stat_descr.conso_gaz_region()
# Out:
# <string>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# De même que pour l'électricité, la consommation de gaz en été n'est pas uniformément répartie
# entre les régions. Il y a une différence de consommation d'environ 1000 Wh par habitant entre
# la normandie et l'Occitanie, les Normands consomment donc 6 fois plus de gaz en moyenne par
# habitants en été que les Occitants. De même, la région Grand Est et les Hauts de France
# consomment 5 fois plus de gaz par habitants que l'Occitanie. Ces écarts n'ont pas la même
# ampleur que pour l'électricité et ils ne concernent pas les mêmes régions, ce qui souligne
# encore une fois le rôle de nouvelles variables explicatives de la consommation d'énergie.
# On peut notamment citer dans le cas des régions Grand Est et Hauts de France la différente
# industrialisation des régions. Leurs première et troisième place dans le classement des régions les plus industrialisés de France peut expliquer leurs consommations importante de gaz. Les évolutions climatiques ne seront pas les seuls facteurs explicatifs de l'évolution de nos consommation d'énergie.

# %%
Stat_descr.conso_we_semaine()
# Out:
# <string>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
#  ## 2) Modèle de prédiction et résultats

# %%
Modelisation.choix_deg_poly()
#Erreur et R2 en fonction du degré du polynome qu'on choisit

# %% [markdown]
# Ces graphiques illustrent un problème auquel on a été confronté et la façon dont on l'a résolu. De fait, après une première visualisation des données, on s'est rendus compte qu'une régression linéaire de degré 1 ne permettait pas de rendre compte de l'évolution de la consommation d'énergie en fonction de la température. C'est pourquoi on a opté pour une régression polynomiale. On a donc du déterminer le degré qui rendait le mieux compte des données. Pour cela il a fallut minimiser l'erreur (graphique 1) et maximiser le R2 (graphique 2). On trouve un degré égal à 4.

# %%
Modelisation.plot_res_modele()

# %% [markdown]
# Ainsi, on obtient un graphique permettant de prédire la consommation d'énergie en France en fonction de la température. On visualise bien une consommation minimale lors d'une température "tempéré" entre 15 et 25 degrés et une consommation qui augmente fortement en dessous de 10 degrés ce qui correspond bien aux constats faits précedemment. On observe aussi une augmentation de la consommation lorsque les températures augmentent au dessus de 25 degrés. Ce sont bien les températures extrêmes qui sont les plus énergivore. Bien que l'on manque de données pour les températures supérieurs à 30 degrés, températures auxquelles nous serons de plus en plus confrontés, on peut d'ores et déjà avancer que la hausse de consommation après les 25 degrés s'amplifie encore, les dépenses énergétiques nouvelles à l'instar de la clim, devenant d'autant plus nécessaire.

# %%
Cartes.carte_pred_conso()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
nuage de point
